# %% [markdown]
# <a href="https://colab.research.google.com/github/likitreddy/house-price-predicton/blob/main/house_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'Product': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Banana'],
    'Quantity': [10, 15, 8, 12, 20, 7, 10, 18],
    'Price': [1.2, 0.5, 0.8, 1.2, 0.5, 0.8, 1.2, 0.5],
    'Date': pd.to_datetime(['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-03', '2023-01-03', '2023-01-01', '2023-01-04'])
}
dot = pd.DataFrame(data)
display(dot)
# Out:
#   Product  Quantity  Price       Date
# 0   Apple        10    1.2 2023-01-01
# 1  Banana        15    0.5 2023-01-01
# 2  Orange         8    0.8 2023-01-02
# 3   Apple        12    1.2 2023-01-02
# 4  Banana        20    0.5 2023-01-03
# 5  Orange         7    0.8 2023-01-03
# 6   Apple        10    1.2 2023-01-01
# 7  Banana        18    0.5 2023-01-04

# %%
print(dot.head())
# Out:
#   Product  Quantity  Price       Date
# 0   Apple        10    1.2 2023-01-01
# 1  Banana        15    0.5 2023-01-01
# 2  Orange         8    0.8 2023-01-02
# 3   Apple        12    1.2 2023-01-02
# 4  Banana        20    0.5 2023-01-03

# %%
print(dot.columns)
# Out:
# Index(['Product', 'Quantity', 'Price', 'Date'], dtype='object')

# %%
print(dot.loc[1])
# Out:
# Product                  Banana
# Quantity                     15
# Price                       0.5
# Date        2023-01-01 00:00:00
# Name: 1, dtype: object

# %%
dot["marks"]=[8,7,6,5,4,3,8,1]
print(dot)
# Out:
#   Product  Quantity  Price       Date  marks
# 0   Apple        10    1.2 2023-01-01      8
# 1  Banana        15    0.5 2023-01-01      7
# 2  Orange         8    0.8 2023-01-02      6
# 3   Apple        12    1.2 2023-01-02      5
# 4  Banana        20    0.5 2023-01-03      4
# 5  Orange         7    0.8 2023-01-03      3
# 6   Apple        10    1.2 2023-01-01      8
# 7  Banana        18    0.5 2023-01-04      1

# %%
print(dot.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   8 non-null      object
#  1   Quantity  8 non-null      int64
#  2   Price     8 non-null      float64
#  3   Date      8 non-null      datetime64[ns]
#  4   marks     8 non-null      int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 452.0+ bytes
# None

# %%
print(dot.describe())
# Out:
#         Quantity     Price                 Date     marks
# count   8.000000  8.000000                    8  8.000000
# mean   12.500000  0.837500  2023-01-02 03:00:00  5.250000
# min     7.000000  0.500000  2023-01-01 00:00:00  1.000000
# 25%     9.500000  0.500000  2023-01-01 00:00:00  3.750000
# 50%    11.000000  0.800000  2023-01-02 00:00:00  5.500000
# 75%    15.750000  1.200000  2023-01-03 00:00:00  7.250000
# max    20.000000  1.200000  2023-01-04 00:00:00  8.000000
# std     4.720775  0.324863                  NaN  2.492847

# %%
print(dot.isnull().sum())
# Out:
# Product     0
# Quantity    0
# Price       0
# Date        0
# marks       0
# dtype: int64

# %%
dot = dot.drop_duplicates()

# %%
print(dot)
# Out:
#   Product  Quantity  Price       Date  marks
# 0   Apple        10    1.2 2023-01-01      8
# 1  Banana        15    0.5 2023-01-01      7
# 2  Orange         8    0.8 2023-01-02      6
# 3   Apple        12    1.2 2023-01-02      5
# 4  Banana        20    0.5 2023-01-03      4
# 5  Orange         7    0.8 2023-01-03      3
# 7  Banana        18    0.5 2023-01-04      1
